# %%
import numpy as np

# %%
arr= np.random.randint(1,100,25)
arr
# Out:
# array([ 6, 61, 71, 66, 15, 40, 60, 57, 59, 36, 69, 52, 15, 19, 25, 54, 69,
#        96, 58, 67, 30, 81, 21, 91, 74], dtype=int32)

# %%
arr=arr.reshape((5,5))
print(arr)
print(arr[2,2])
# Out:
# [[ 6 61 71 66 15]
#  [40 60 57 59 36]
#  [69 52 15 19 25]
#  [54 69 96 58 67]
#  [30 81 21 91 74]]
# 15

# %%
print(np.mean(arr,axis=1))
# Out:
# [43.8 50.4 36.  68.8 59.4]

# %%
g=np.mean(arr)
print(g)
# Out:
# 51.68

# %%
arry=arr[arr> np.mean(arr)]
print(arry)
# Out:
# [61 71 66 60 57 59 69 52 54 69 96 58 67 81 91 74]

# %%
def numpy_spiral_order(matrix):
    if len(matrix) == 0:
        return []
    
    result = []
    top, bottom, left, right = 0, len(matrix) - 1, 0, len(matrix[0]) - 1
    
    while top <= bottom and left <= right:
        # Traverse from left to right along the top row
        for i in range(left, right + 1):
            result.append(matrix[top][i])
        top += 1
        
        # Traverse from top to bottom along the rightmost column
        for i in range(top, bottom + 1):
            result.append(matrix[i][right])
        right -= 1
        
        if top <= bottom:
            # Traverse from right to left along the bottom row
            for i in range(right, left - 1, -1):
                result.append(matrix[bottom][i])
            bottom -= 1
        
        if left <= right:
            # Traverse from bottom to top along the leftmost column
            for i in range(bottom, top - 1, -1):
                result.append(matrix[i][left])
            left += 1
    return result

# %%
g=numpy_spiral_order(arr)
g=[int(x) for x in g]
print(g)
# Out:
# [6, 61, 71, 66, 15, 36, 25, 67, 74, 91, 21, 81, 30, 54, 69, 40, 60, 57, 59, 19, 58, 96, 69, 52, 15]

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('videogamesales.csv')
df=pd.DataFrame(data)
df['global_sales']=df['NA_Sales']+df['EU_Sales']+df['JP_Sales']+df['Other_Sales']
df
# Out:
#                                              Name Platform    Year     Genre  \
# 0                                       Asteroids     2600  1980.0   Shooter
# 1                                 Missile Command     2600  1980.0   Shooter
# 2                                         Kaboom!     2600  1980.0      Misc
# 3                                        Defender     2600  1980.0      Misc
# 4                                          Boxing     2600  1980.0  Fighting
# ...                                           ...      ...     ...       ...
# 16578           WRC: FIA World Rally Championship     X360     NaN    Racing
# 16579           WRC: FIA World Rally Championship       PC     NaN    Racing
# 16580  Writing and Speaking Beautiful Japanese DS       DS     NaN      Misc
# 16581  Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii     NaN    Racing
# 16582                    Zero: Tsukihami no Kamen      Wii     NaN    Action
#
# ...

# %%
df.sort_values(by=['global_sales'], ascending=False)
# Out:
#                                                    Name Platform    Year  \
# 6109                                         Wii Sports      Wii  2006.0
# 122                                   Super Mario Bros.      NES  1985.0
# 8315                                     Mario Kart Wii      Wii  2008.0
# 9743                                  Wii Sports Resort      Wii  2009.0
# 705                            Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 12371                   Tenjin Ranman: Happy GO Lucky!!      PSP  2010.0
# 12374                      The Eye of Judgment: Legends      PSP  2010.0
# 12393                           Tropico 3: Gold Edition       PC  2010.0
# 1895                                    Builder's Block       PS  1999.0
# 9650   SCORE International Baja 1000: The Official Game      PS2  2008.0
#
#               Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df.groupby(['Genre']).sum()
plt.plot(df['global_sales'])
plt.show()

# %%
df_filter = df[df["Name"].str.contains("Grand Theft Auto")]
df['sum']=df['EU_Sales']+df['JP_Sales']
df_filter
# Out:
#                                                     Name Platform    Year  \
# 999                                     Grand Theft Auto       PS  1997.0
# 1290                                  Grand Theft Auto 2       PS  1998.0
# 1469      Grand Theft Auto: Mission Pack #1, London 1969       PS  1998.0
# 2323                                Grand Theft Auto III      PS2  2001.0
# 2805                         Grand Theft Auto: Vice City      PS2  2002.0
# 3563                                Grand Theft Auto III       PC  2002.0
# 3639   Rockstar Games Double Pack: Grand Theft Auto I...       XB  2003.0
# 3688   Rockstar Games Double Pack: Grand Theft Auto I...      PS2  2003.0
# 4356                         Grand Theft Auto: Vice City       PC  2003.0
# 4405                       Grand Theft Auto: San Andreas      PS2  2004.0
# 4704                                    Grand Theft Auto      GBA  2004.0
# 5173              Grand Theft Auto: Liberty City Stories      PSP  2005.0
# ...

# %%
df_filter.filter(items=['Name','Platform','Year','sum'])
# Out:
#                                                     Name Platform    Year
# 999                                     Grand Theft Auto       PS  1997.0
# 1290                                  Grand Theft Auto 2       PS  1998.0
# 1469      Grand Theft Auto: Mission Pack #1, London 1969       PS  1998.0
# 2323                                Grand Theft Auto III      PS2  2001.0
# 2805                         Grand Theft Auto: Vice City      PS2  2002.0
# 3563                                Grand Theft Auto III       PC  2002.0
# 3639   Rockstar Games Double Pack: Grand Theft Auto I...       XB  2003.0
# 3688   Rockstar Games Double Pack: Grand Theft Auto I...      PS2  2003.0
# 4356                         Grand Theft Auto: Vice City       PC  2003.0
# 4405                       Grand Theft Auto: San Andreas      PS2  2004.0
# 4704                                    Grand Theft Auto      GBA  2004.0
# 5173              Grand Theft Auto: Liberty City Stories      PSP  2005.0
# ...

# %%
plt.pie(df_filter['global_sales'], labels=df_filter['Name'])
plt.show()
